# %% [markdown]
# <a href="https://colab.research.google.com/github/weijhenyujhou/DS_IBM/blob/master/Databases%20and%20SQL%20for%20Data%20Science%20with%20Python/Database_and_SQL_Final_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade ibm_db
# !pip install --upgrade ibm_db_sa
# !pip install --upgrade SQLAlchemy
# Out:
# Collecting ibm_db
#   Downloading https://files.pythonhosted.org/packages/dc/7c/26c1eb0ce78689a6a6775337b43f498f8e901790ec0bafd6f24e2ef594af/ibm_db-3.0.4.tar.gz (796kB)
#      |████████████████████████████████| 798kB 3.9MB/s
# Building wheels for collected packages: ibm-db
#   Building wheel for ibm-db (setup.py) ... done
#   Created wheel for ibm-db: filename=ibm_db-3.0.4-cp37-cp37m-linux_x86_64.whl size=40999820 sha256=09b275e716dc3387d9f76bbeb2358c2f918861dbe259e9e9b1ac4161ef29f4c2
#   Stored in directory: /root/.cache/pip/wheels/d9/85/7a/07dd5eba2f2d6a040be8aefb2b5051b0408c7f997259b5756b
# Successfully built ibm-db
# Installing collected packages: ibm-db
# Successfully installed ibm-db-3.0.4
# Collecting ibm_db_sa
#   Downloading https://files.pythonhosted.org/packages/62/af/88781f8dc7a414507ab94a2b91319bdbd3b5375e38353446c113c548adcb/ibm_db_sa-0.3.6.tar.gz
# Requirement already satisfied, skipping upgrade: sqlalchemy>=0.7.3 in /usr/local/lib/python3.7/dist-packages (from ibm_db_sa) (1.4.15)
# Requirement already satisfied, skipping upgrade: ibm_db>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from ibm_db_sa) (3.0.4)
# Requirement already satisfied, skipping upgrade: greenlet!=0.4.17; python_version >= "3" in /usr/local/lib/python3.7/dist-packages (from sqlalchemy>=0.7.3->ibm_db_sa) (1.1.0)
# Requirement already satisfied, skipping upgrade: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from sqlalchemy>=0.7.3->ibm_db_sa) (4.0.1)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->sqlalchemy>=0.7.3->ibm_db_sa) (3.4.1)
# Requirement already satisfied, skipping upgrade: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->sqlalchemy>=0.7.3->ibm_db_sa) (3.7.4.3)
# Building wheels for collected packages: ibm-db-sa
#   Building wheel for ibm-db-sa (setup.py) ... done
#   Created wheel for ibm-db-sa: filename=ibm_db_sa-0.3.6-cp37-none-any.whl size=28873 sha256=8793ed8b4371e36fef37011785c9dcb3743dae8d49c07b2020c3bdd49b2eda0d
#   Stored in directory: /root/.cache/pip/wheels/97/b5/8a/17a01086a100d48a008b2b556843b23fef5eb69a6b4f04c419
# Successfully built ibm-db-sa
# Installing collected packages: ibm-db-sa
# Successfully installed ibm-db-sa-0.3.6
# Collecting SQLAlchemy
#   Downloading https://files.pythonhosted.org/packages/36/30/be03c3d4d439e9f4c996eff39ec023206d325280317108af3412588bd86a/SQLAlchemy-1.4.17-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.5MB)
#      |████████████████████████████████| 1.5MB 3.9MB/s
# Requirement already satisfied, skipping upgrade: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from SQLAlchemy) (4.0.1)
# Requirement already satisfied, skipping upgrade: greenlet!=0.4.17; python_version >= "3" in /usr/local/lib/python3.7/dist-packages (from SQLAlchemy) (1.1.0)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->SQLAlchemy) (3.4.1)
# Requirement already satisfied, skipping upgrade: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->SQLAlchemy) (3.7.4.3)
# Installing collected packages: SQLAlchemy
#   Found existing installation: SQLAlchemy 1.4.15
#     Uninstalling SQLAlchemy-1.4.15:
#       Successfully uninstalled SQLAlchemy-1.4.15
# Successfully installed SQLAlchemy-1.4.17

# %%
import ibm_db
#import ibm_db_sa
import sqlalchemy

# %%
# %load_ext sql

# %%
# Remember the connection string is of the format:
# %sql ibm_db_sa://my-username:my-password@my-hostname:my-port/my-db-name
# Enter the connection string for your Db2 on Cloud database instance below
# i.e. copy after db2:// from the URI string in Service Credentials of your Db2 instance. Remove the double quotes at the end.
# %sql ibm_db_sa://msb52107:59kj282nqkg1h2-d@dashdb-txn-sbox-yp-lon02-02.services.eu-gb.bluemix.net:50000/BLUDB
# Out:
# DB2/LINUXX8664
# 'Connected: msb52107@BLUDB'

# %%
# !pip install ibm_db
# Out:
# Collecting ibm_db
#   Downloading https://files.pythonhosted.org/packages/dc/7c/26c1eb0ce78689a6a6775337b43f498f8e901790ec0bafd6f24e2ef594af/ibm_db-3.0.4.tar.gz (796kB)
#      |████████████████████████████████| 798kB 5.2MB/s
# Building wheels for collected packages: ibm-db
#   Building wheel for ibm-db (setup.py) ... done
#   Created wheel for ibm-db: filename=ibm_db-3.0.4-cp37-cp37m-linux_x86_64.whl size=40999794 sha256=d211c7af4f03efb3811a283c980f18057b9d608c7790e8d2c532bd0e08a14037
#   Stored in directory: /root/.cache/pip/wheels/d9/85/7a/07dd5eba2f2d6a040be8aefb2b5051b0408c7f997259b5756b
# Successfully built ibm-db
# Installing collected packages: ibm-db
# Successfully installed ibm-db-3.0.4

# %%
import ibm_db

# %%
#Replace the placeholder values with the actuals for your Db2 Service Credentials
dsn_driver = "{IBM DB2 ODBC DRIVER}"
dsn_database = "BLUDB"            # e.g. "BLUDB"
dsn_hostname = "dashdb-txn-sbox-yp-lon02-02.services.eu-gb.bluemix.net"            # e.g.: "dashdb-txn-sbox-yp-dal09-04.services.dal.bluemix.net"
dsn_port = "50000"                    # e.g. "50000" 
dsn_protocol = "TCPIP"            # i.e. "TCPIP"
dsn_uid = "msb52107"                 # e.g. "abc12345"
dsn_pwd = "59kj282nqkg1h2-d"                 # e.g. "7dBZ3wWt9XN6$o0J"

# %%
#Create database connection
#DO NOT MODIFY THIS CELL. Just RUN it with Shift + Enter
dsn = (
    "DRIVER={0};"
    "DATABASE={1};"
    "HOSTNAME={2};"
    "PORT={3};"
    "PROTOCOL={4};"
    "UID={5};"
    "PWD={6};").format(dsn_driver, dsn_database, dsn_hostname, dsn_port, dsn_protocol, dsn_uid, dsn_pwd)

try:
    conn = ibm_db.connect(dsn, "", "")
    print ("Connected to database: ", dsn_database, "as user: ", dsn_uid, "on host: ", dsn_hostname)

except:
    print ("Unable to connect: ", ibm_db.conn_errormsg() )
# Out:
# Connected to database:  BLUDB as user:  msb52107 on host:  dashdb-txn-sbox-yp-lon02-02.services.eu-gb.bluemix.net

# %%
import pandas
import ibm_db_dbi

# %%
#connection for pandas
pconn = ibm_db_dbi.Connection(conn)

# %%
#query statement to retrieve all rows in INSTRUCTOR table
selectQuery = "select * from INSTRUCTOR"

#retrieve the query results into a pandas dataframe
pdf = pandas.read_sql(selectQuery, pconn)

#print just the LNAME for first row in the pandas data frame
pdf.LNAME[0]
# Out:
# 'Ahuja'

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# # Problem 1: Find the total number of crimes recorded in the CRIME table.#

# %%
# %sql Select count(*) from chicago_socioeconomic_data
# Out:
#  * ibm_db_sa://msb52107:***@dashdb-txn-sbox-yp-lon02-02.services.eu-gb.bluemix.net:50000/BLUDB
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-507c491b0c70> in <module>()
# ----> 1 get_ipython().magic('sql Select count(*) from chicago_socioeconomic_data')
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py in magic(self, arg_s)
#    2158         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2159         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2160         return self.run_line_magic(magic_name, magic_arg_s)
#    2161
#    2162     #-------------------------------------------------------------------------
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line)
#    2079                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2080             with self.builtin_trap:
# -> 2081                 result = fn(*args,**kwargs)
#    2082             return result
#    2083
#
# <decorator-gen-116> in execute(self, line, cell, local_ns)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# <decorator-gen-115> in execute(self, line, cell, local_ns)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /usr/local/lib/python3.7/dist-packages/sql/magic.py in execute(self, line, cell, local_ns)
#      93
#      94         try:
# ---> 95             result = sql.run.run(conn, parsed['sql'], self, user_ns)
#      96
#      97             if result is not None and not isinstance(result, str) and self.column_local_vars:
#
# /usr/local/lib/python3.7/dist-packages/sql/run.py in run(conn, sql, config, user_namespace)
#     339                 txt = sqlalchemy.sql.text(statement)
#     340                 result = conn.session.execute(txt, user_namespace)
# --> 341             _commit(conn=conn, config=config)
#     342             if result and config.feedback:
#     343                 print(interpret_rowcount(result.rowcount))
#
# /usr/local/lib/python3.7/dist-packages/sql/run.py in _commit(conn, config)
#     318     if _should_commit:
#     319         try:
# --> 320             conn.session.execute('commit')
#     321         except sqlalchemy.exc.OperationalError:
#     322             pass  # not all engines can commit
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    1250                 params,
#    1251                 _EMPTY_EXECUTION_OPTS,
# -> 1252                 future=False,
#    1253             )
#    1254
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/base.py in _exec_driver_sql(self, statement, multiparams, params, execution_options, future)
#    1551             execution_options,
#    1552             statement,
# -> 1553             distilled_parameters,
#    1554         )
#    1555
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1694             self._autobegin()
#    1695
# -> 1696         context.pre_exec()
#    1697
#    1698         if dialect.use_setinputsizes:
#
# /usr/local/lib/python3.7/dist-packages/ibm_db_sa/ibm_db.py in pre_exec(self)
#      52     def pre_exec(self):
#      53         # if a single execute, check for outparams
# ---> 54         if len(self.compiled_parameters) == 1:
#      55             for bindparam in self.compiled.binds.values():
#      56                 if bindparam.isoutparam:
#
# AttributeError: 'DB2ExecutionContext_ibm_db' object has no attribute 'compiled_parameters'
